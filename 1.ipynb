# %% [markdown]
# source .venv/bin/activate

# %%
import torch

# %%
data_list = [1, 2]

tensor = torch.tensor(data_list)
tensor
# Out:
# tensor([1, 2])

# %%
type(tensor)
# Out:
# torch.Tensor

# %%
print(f'data type: {tensor.dtype}')
# Out:
# data type: torch.int64

# %%
print(f'number of dimensions: {tensor.ndim}')
# Out:
# number of dimensions: 1

# %%
print(f'shape: {tensor.shape}')
# Out:
# shape: torch.Size([2])

# %%
print(f'size: {tensor.size()}')
# Out:
# size: torch.Size([2])

# %%
import numpy as np

data_np = np.array(
    [
        [1, 2],
        [3, 4]
    ]
)

# numpy 배열을 torch 텐서로 변환
tensor_np = torch.tensor(data_np)
tensor_np
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
# numpy 배열을 공유함. 따라서 numpy 배열을 변경하면 torch 텐서도 변경됨
tensor_from_numpy = torch.from_numpy(data_np)
tensor_from_numpy
# Out:
# tensor([[1, 2],
#         [3, 4]])

# %%
data_np[0, 0] = -1

print(f'torch.tensor() result\n{tensor_np}\n')

print(f'torch.from_numpy() result\n{tensor_from_numpy}')
# Out:
# torch.tensor() result
# tensor([[1, 2],
#         [3, 4]])
#
# torch.from_numpy() result
# tensor([[-1,  2],
#         [ 3,  4]])

# %%
print(tensor.dtype)

print(tensor_np.dtype)

# 기본은 int형임
# Out:
# torch.int64
# torch.int64

# %%
tensor = torch.tensor([1, 1.5])
tensor.dtype
# Out:
# torch.float32

# %%
tensor = torch.tensor([1, 2, 3], dtype=torch.float32)
tensor.dtype
# Out:
# torch.float32

# %%
torch.rand(2, 3)
# Out:
# tensor([[0.4324, 0.9517, 0.0902],
#         [0.2789, 0.0665, 0.6792]])

# %%
# 리스트
torch.rand([2, 3])
# Out:
# tensor([[0.2568, 0.8984, 0.7366],
#         [0.4144, 0.2340, 0.7091]])

# %%
# 튜플
torch.rand((2, 3))
# Out:
# tensor([[0.7467, 0.4716, 0.5293],
#         [0.4915, 0.8716, 0.9973]])

# %%
torch.randn(2, 3)
# Out:
# tensor([[ 0.0159,  0.8213, -0.1489],
#         [-0.3494,  1.6332,  1.1701]])

# %% [markdown]
# 파이썬 리스트 data_list와 NumPy array data_np가 주어져 있습니다. 이 두 데이터를 PyTorch 텐서로 만들어 주세요.
#
# data_list에서 만든 텐서는 tensor_from_list 변수에 저장하고, data_np에서 만든 텐서는 tensor_from_np_array에 저장해야 합니다.

# %%
import numpy as np
import torch

data_list = [
    [1, 1],
    [-1, -1],
]

data_np = np.array(
    [
        [3, 4],
        [5,6]
    ]
)

tensor_from_list = torch.tensor(data_list)

tensor_from_np_array = torch.from_numpy(data_np)

print(tensor_from_list)
print(tensor_from_np_array)
# Out:
# tensor([[ 1,  1],
#         [-1, -1]])
# tensor([[3, 4],
#         [5, 6]])
